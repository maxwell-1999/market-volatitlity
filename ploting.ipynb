# %%
import csv
import math
def rawSD(close_prices):
    mean = sum(close_prices) / len(close_prices)
    diff = [(close_prices[i] - mean) ** 2 for i in range(len(close_prices))]
    varience = sum(diff) / (len(close_prices))
    sd = math.sqrt(varience)
    return sd
def round_dec(num):
    return round(num*100,4)

# %%
with open('SampleOHLC.csv',mode = 'r') as file:
    btc_usd = csv.DictReader(file)

#     PARKINSON
    arr = [i for i in btc_usd]    
    arr = arr[0:-3]
    # print('arr: ',arr)
    high_by_low_deviation = [(math.log(float(arr[i]['High'])/float(arr[i]['Low']))**2) for i in range(len(arr))]
    print('h2l: ',high_by_low_deviation)
# #    last *len(h2l) is doubted in varience, it is not present in sheet https://docs.google.com/spreadsheets/d/1lQTz1Fad2TIi42-jBjwd-42UWKsIuSP1/edit#gid=1351734694
    parkinson_varience = (sum(high_by_low_deviation)/len(high_by_low_deviation))/(4*math.log(2))
    # print('parkinson_varience: ',parkinson_varience)
    parkinson_volatility = math.sqrt(parkinson_varience)
    print('parkinson_volatility:',math.log(2))
    
# #     KLASS
#     c2o = [math.log(float(arr[i]['Close'])/float(arr[i]['Open']))**2 for i in range(len(arr))]
#     gk_varience = [h2l[i]*0.5 + c2o[i]*(2*math.log(2) - 1) for i in range(len(c2o))]
#     garman_klass = math.sqrt(sum(gk_varience)/len(gk_varience))
#     print('garman_klass:',garman_klass)
    
    
# #     Yang Zhang
#     o = [float(arr[i]['Open'])/float(arr[i-1]['Close']) for i in  range(1, len(arr))]
#     next_open_sd = rawSD(o)
#     c2o_sd = rawSD(c2o)
#     n = len(arr)-1
#     k = 0.34/(1.34+((n+1)/(n-1)))
#     u = [math.log(float(arr[i]['High'])/float(arr[i]['Open']))**2 for i in range(len(arr))]
#     d = [math.log(float(arr[i]['Low'])/float(arr[i]['Open']))**2 for i in range(len(arr))]
#     rs_arr = [u[i]*(u[i] - c2o[i]) + d[i]*(d[i] - c2o[i]) for i in range(len(u))]
#     rs = math.sqrt(sum(rs_arr)/(n+1))
#     yang_zhang = math.sqrt(next_open_sd**2 + k**2 + (1-k)*(rs**2))
#     print('yang_zhang:',yang_zhang)
# Out:
# h2l:  [0.0001779959306180079, 0.00016337535194545713, 0.00033209568923904943, 0.0003533993884672814, 0.0001422132335926602, 0.00026726907193031814, 0.00016188272187967902, 0.00017224849072191114, 0.000573644838586046, 0.00022364325044748113, 0.00022178791196248687, 0.0002603620948528541, 0.00014698712963282106, 0.0001680157328578349, 0.0003495120050877071, 3.65827352100529e-05, 6.601221308959819e-05, 0.0001888532691852114, 0.00041118708804162106, 0.0003122081720792283, 0.00022224954346353597, 0.0004148419497296872, 0.00018354633833375563, 7.759228858340655e-05, 9.580973420791916e-05, 0.0001184222128875196, 4.85699364848333e-05, 0.00011658782450968252, 5.622865428544504e-05, 7.959358751028067e-05, 2.4385692939716974e-05, 3.0116313226791744e-05, 1.4858073670144897e-05, 2.925870268109756e-05, 0.00014393139387621322, 1.1200716613979435e-05, 3.2663908300278065e-05, 2.1039287654339364e-05, 2.3165867046715687e-05, 1.818354441168149e-05, 3.804031816902475e-05, 6.898392